# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
df.tail(25)
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 32535   34            Private  160216      Bachelors             13
# 32536   30            Private  345898        HS-grad              9
# 32537   38            Private  139180      Bachelors             13
# 32538   71                  ?  287372      Doctorate             16
# 32539   45          State-gov  252208        HS-grad              9
# 32540   41                  ?  202822        HS-grad              9
# 32541   72                  ?  129912        HS-grad              9
# 32542   45          Local-gov  119199     Assoc-acdm             12
# 32543   31            Private  199655        Masters             14
# 32544   39          Local-gov  111499     Assoc-acdm             12
# 32545   37            Private  198216     Assoc-acdm             12
# 32546   43            Private  260761        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Capital_gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours_per_week      40.0      45.0       99.0

# %%
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
df['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
df['Race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
df['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
sns.countplot(df['Income'], hue='Relationship', data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df['Income'], hue='Workclass', data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df['Income'], hue='Sex', data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df['Income'], hue='Marital_status', data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
df['Workclass'] = df['Workclass'].str.replace('?','Private')
df['Occupation'] = df['Occupation'].str.replace('?','Prof-specialty')
df['Native_country'] = df['Native_country'].str.replace('?','United-States')

# %%
df.tail(30)
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 32530   30            Private   33811      Bachelors             13
# 32531   34            Private  204461      Doctorate             16
# 32532   54            Private  337992      Bachelors             13
# 32533   37            Private  179137   Some-college             10
# 32534   22            Private  325033           12th              8
# 32535   34            Private  160216      Bachelors             13
# 32536   30            Private  345898        HS-grad              9
# 32537   38            Private  139180      Bachelors             13
# 32538   71            Private  287372      Doctorate             16
# 32539   45          State-gov  252208        HS-grad              9
# 32540   41            Private  202822        HS-grad              9
# 32541   72            Private  129912        HS-grad              9
# 32542   45          Local-gov  119199     Assoc-acdm             12
# ...

# %%
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %%
df.hist(figsize=(12,12),layout=(3,3),sharex=False);

# %%
df.plot(kind='box',figsize=(12,12),layout=(3,3),sharex=False,subplots=True);

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_col = ['Income']
lab_enc = LabelEncoder()
df[lab_col] = df[lab_col].apply(lambda x : lab_enc.fit_transform(x))

# %%
label_col = ['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country']
lab_enc = LabelEncoder()
df[label_col] = df[label_col].apply(lambda x : lab_enc.fit_transform(x))

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
X = df.drop(['Income'],axis=1)
y = df.Income

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scaler = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaler,y,test_size=0.25,random_state=355)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score,roc_curve,accuracy_score,precision_score,confusion_matrix,recall_score
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score,cross_val_predict

# %%
def print_score(clf,X_train,X_test,y_train,y_test,train=True):
    if train:
        y_pred = clf.predict(X_train)
        print("\n ===Train result===")
        print(f"Accuracy Score:{accuracy_score(y_train,y_pred)*100:.2f}%")
    elif train==False:
        pred = clf.predict(X_test)
        print("\n ===Test result===")
        print(f"Accuracy Score:{accuracy_score(y_test,pred)*100:.2f}%")
        print('\n \n Test classification report \n',classification_report(y_test,pred,digits=2))

# %%
svc = SVC()
svc.fit(X_train,y_train)
print_score(svc,X_train,X_test,y_train,y_test,train=True)
print_score(svc,X_train,X_test,y_train,y_test,train=False)
# Out:
#  ===Train result===
# Accuracy Score:85.86%
#
#  ===Test result===
# Accuracy Score:84.42%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      6160
#            1       0.73      0.56      0.64      1980
#
#     accuracy                           0.84      8140
#    macro avg       0.80      0.75      0.77      8140
# weighted avg       0.84      0.84      0.84      8140

# %%
gbdt = GradientBoostingClassifier()
gbdt.fit(X_train,y_train)
print_score(gbdt,X_train,X_test,y_train,y_test,train=True)
print_score(gbdt,X_train,X_test,y_train,y_test,train=False)
# Out:
#  ===Train result===
# Accuracy Score:86.81%
#
#  ===Test result===
# Accuracy Score:86.20%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      6160
#            1       0.78      0.61      0.68      1980
#
#     accuracy                           0.86      8140
#    macro avg       0.83      0.78      0.80      8140
# weighted avg       0.86      0.86      0.86      8140

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
print_score(rf,X_train,X_test,y_train,y_test,train=True)
print_score(rf,X_train,X_test,y_train,y_test,train=False)
# Out:
#  ===Train result===
# Accuracy Score:100.00%
#
#  ===Test result===
# Accuracy Score:85.17%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      6160
#            1       0.72      0.64      0.68      1980
#
#     accuracy                           0.85      8140
#    macro avg       0.80      0.78      0.79      8140
# weighted avg       0.85      0.85      0.85      8140

# %%
dc = DecisionTreeClassifier()
dc.fit(X_train,y_train)
print_score(dc,X_train,X_test,y_train,y_test,train=True)
print_score(dc,X_train,X_test,y_train,y_test,train=False)
# Out:
#  ===Train result===
# Accuracy Score:100.00%
#
#  ===Test result===
# Accuracy Score:80.97%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      6160
#            1       0.61      0.62      0.61      1980
#
#     accuracy                           0.81      8140
#    macro avg       0.74      0.75      0.74      8140
# weighted avg       0.81      0.81      0.81      8140

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
print_score(lr,X_train,X_test,y_train,y_test,train=True)
print_score(lr,X_train,X_test,y_train,y_test,train=False)
# Out:
#  ===Train result===
# Accuracy Score:82.54%
#
#  ===Test result===
# Accuracy Score:82.29%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      6160
#            1       0.71      0.46      0.56      1980
#
#     accuracy                           0.82      8140
#    macro avg       0.78      0.70      0.72      8140
# weighted avg       0.81      0.82      0.81      8140

# %% [markdown]
#
#
#             GradientBoostingClassifier is better than all

# %%
grid_param = {'max_depth':range(4,8),'min_samples_split':range(2,8,2),'learning_rate':np.arange(0.01,0.2)}

# %%
grid = GridSearchCV(GradientBoostingClassifier(),param_grid=grid_param)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': array([0.01]),
#                          'max_depth': range(4, 8),
#                          'min_samples_split': range(2, 8, 2)})

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 6, 'min_samples_split': 6}

# %%
gbdt = GradientBoostingClassifier(max_depth=6,min_samples_split=6,learning_rate=0.1)
gbdt.fit(X_train,y_train)
print_score(gbdt,X_train,X_test,y_train,y_test,train=True)
print_score(gbdt,X_train,X_test,y_train,y_test,train=False)
# Out:
#  ===Train result===
# Accuracy Score:89.61%
#
#  ===Test result===
# Accuracy Score:86.74%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91      6160
#            1       0.76      0.66      0.71      1980
#
#     accuracy                           0.87      8140
#    macro avg       0.83      0.80      0.81      8140
# weighted avg       0.86      0.87      0.86      8140
